# %%
# !mkdir -p data/raw
# !wget -O data/raw/matriculas.csv 'https://www.datos.gov.co/api/views/a3jg-j674/rows.csv?accessType=DOWNLOAD'
# Out:
# --2026-06-06 01:23:43--  https://www.datos.gov.co/api/views/a3jg-j674/rows.csv?accessType=DOWNLOAD
# Resolving www.datos.gov.co (www.datos.gov.co)... 52.206.140.199, 52.206.68.26, 52.206.140.205
# Connecting to www.datos.gov.co (www.datos.gov.co)|52.206.140.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘data/raw/matriculas.csv’
#
# data/raw/matriculas     [    <=>             ]   3.26M  4.77MB/s    in 0.7s
#
# 2026-06-06 01:23:44 (4.77 MB/s) - ‘data/raw/matriculas.csv’ saved [3416953]

# %%
df = pd.read_csv('data/raw/matriculas.csv')
print(df.shape)
df.head()
# Out:
# (13461, 21)
#       Género Municipio de Nacimiento      País Municipio Dirección  \
# 0   Femenino                Medellín  Colombia            Envigado
# 1   Femenino                Envigado  Colombia            Envigado
# 2  Masculino                  Bogotá  Colombia             La Mesa
# 3  Masculino                Envigado  Colombia            Envigado
# 4  Masculino                Medellín  Colombia            Envigado
#
#   Barrio Dirección  Estrato Estado civil  \
# 0       Las Flores      3.0   Soltero(a)
# 1         San José      2.0   Soltero(a)
# 2    Sin respuesta      3.0   Soltero(a)
# 3         San José      2.0   Soltero(a)
# 4        El Salado      2.0   Soltero(a)
#
#                                     EPS   Grupo Sisben    Zona  ...  \
# 0                              EPS Sura  Sin respuesta  Urbana  ...
# 1                              EPS Sura  Sin respuesta  Urbana  ...
# 2                             No Aplica  Sin respuesta   Rural  ...
# ...

# %%
import os
from getpass import getpass

GITHUB_USER = "LuisBetancourt11"
REPO        = "Proyecto_Ciencia_Datos"
TOKEN       = getpass("Pega tu Personal Access Token: ")  # no lo escribas en duro

if not os.path.exists(REPO):
    # !git clone https://{GITHUB_USER}:{TOKEN}@github.com/{GITHUB_USER}/{REPO}.git
# %cd {REPO}
# Out:
# Pega tu Personal Access Token: ··········
# Cloning into 'Proyecto_Ciencia_Datos'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 45 (delta 12), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 320.17 KiB | 4.33 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/Proyecto_Ciencia_Datos/Proyecto_Ciencia_Datos/Proyecto_Ciencia_Datos

# %%
# !git config user.email "betancourtl659@gmail.com"
# !git config user.name  "Luis Betancourt"
# !git add data/raw/matriculas.csv
# !git commit -m "Agregar dataset de matrículas descargado vía API"
# !git push
# Out:
# [main 63e02d5] Agregar dataset de matrículas descargado vía API
#  1 file changed, 13462 insertions(+)
#  create mode 100644 data/raw/matriculas.csv
# remote: Permission to LuisBetancourt11/Proyecto_Ciencia_Datos.git denied to LuisBetancourt11.
# fatal: unable to access 'https://github.com/LuisBetancourt11/Proyecto_Ciencia_Datos.git/': The requested URL returned error: 403

# %%
from getpass import getpass
TOKEN = getpass("Token: ")

# !git remote set-url origin https://LuisBetancourt11:{TOKEN}@github.com/LuisBetancourt11/Proyecto_Ciencia_Datos.git
# !git push
# Out:
# Token: ··········
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 306.66 KiB | 3.93 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/LuisBetancourt11/Proyecto_Ciencia_Datos.git
#    6fecf02..63e02d5  main -> main
